# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218
# 2013-01-06  0.006860  1.196373  1.928233  0.121686

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })
df2
# Out:
#    A          B  C  D      E    F
# 0  1 2013-01-02  1  3   test  foo
# 1  1 2013-01-02  1  3  train  foo
# 2  1 2013-01-02  1  3   test  foo
# 3  1 2013-01-02  1  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218
# 2013-01-06  0.006860  1.196373  1.928233  0.121686

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.55652362,  0.386633  , -0.35261448,  0.86409413],
#        [-0.97484712, -0.02440867,  0.66619199,  0.25775195],
#        [-2.17950904, -1.47452328,  0.06068497,  0.84874102],
#        [ 1.16319896,  0.37327004,  0.20454962, -1.06549056],
#        [ 0.70604488,  0.61430373, -1.14144147,  1.41721826],
#        [ 0.00685983,  1.19637274,  1.92823267,  0.12168641]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.120288  0.178608  0.227601  0.407334
# std    1.247002  0.903427  1.031875  0.859828
# min   -2.179509 -1.474523 -1.141441 -1.065491
# 25%   -0.729420  0.075011 -0.249290  0.155703
# 50%    0.281692  0.379952  0.132617  0.553246
# 75%    0.668665  0.557386  0.550781  0.860256
# max    1.163199  1.196373  1.928233  1.417218

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.556524   -0.974847   -2.179509    1.163199    0.706045    0.006860
# B    0.386633   -0.024409   -1.474523    0.373270    0.614304    1.196373
# C   -0.352614    0.666192    0.060685    0.204550   -1.141441    1.928233
# D    0.864094    0.257752    0.848741   -1.065491    1.417218    0.121686

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.864094 -0.352614  0.386633  0.556524
# 2013-01-02  0.257752  0.666192 -0.024409 -0.974847
# 2013-01-03  0.848741  0.060685 -1.474523 -2.179509
# 2013-01-04 -1.065491  0.204550  0.373270  1.163199
# 2013-01-05  1.417218 -1.141441  0.614304  0.706045
# 2013-01-06  0.121686  1.928233  1.196373  0.006860

# %%
df.sort(columns='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218
# 2013-01-06  0.006860  1.196373  1.928233  0.121686

# %%
df['A']
# Out:
# 2013-01-01    0.556524
# 2013-01-02   -0.974847
# 2013-01-03   -2.179509
# 2013-01-04    1.163199
# 2013-01-05    0.706045
# 2013-01-06    0.006860
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491

# %%
df.loc[dates[0]]
# Out:
# A    0.556524
# B    0.386633
# C   -0.352614
# D    0.864094
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.556524  0.386633
# 2013-01-02 -0.974847 -0.024409
# 2013-01-03 -2.179509 -1.474523
# 2013-01-04  1.163199  0.373270
# 2013-01-05  0.706045  0.614304
# 2013-01-06  0.006860  1.196373

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.974847 -0.024409
# 2013-01-03 -2.179509 -1.474523
# 2013-01-04  1.163199  0.373270

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -0.974847
# B   -0.024409
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 0.55652361824897545

# %%
df.at[dates[0],'A']
# Out:
# 0.55652361824897545

# %%
df.iloc[3]
# Out:
# A    1.163199
# B    0.373270
# C    0.204550
# D   -1.065491
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  1.163199  0.373270
# 2013-01-05  0.706045  0.614304

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.974847  0.666192
# 2013-01-03 -2.179509  0.060685
# 2013-01-05  0.706045 -1.141441

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  0.386633 -0.352614
# 2013-01-02 -0.024409  0.666192
# 2013-01-03 -1.474523  0.060685
# 2013-01-04  0.373270  0.204550
# 2013-01-05  0.614304 -1.141441
# 2013-01-06  1.196373  1.928233

# %%
df.iloc[1,1]
# Out:
# -0.024408666477233356

# %%
df.iat[1,1]
# Out:
# -0.024408666477233356

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218
# 2013-01-06  0.006860  1.196373  1.928233  0.121686

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.556524  0.386633       NaN  0.864094
# 2013-01-02       NaN       NaN  0.666192  0.257752
# 2013-01-03       NaN       NaN  0.060685  0.848741
# 2013-01-04  1.163199  0.373270  0.204550       NaN
# 2013-01-05  0.706045  0.614304       NaN  1.417218
# 2013-01-06  0.006860  1.196373  1.928233  0.121686

# %%
df2 = df.copy()
df2['E']=['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.556524  0.386633 -0.352614  0.864094    one
# 2013-01-02 -0.974847 -0.024409  0.666192  0.257752    one
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741    two
# 2013-01-04  1.163199  0.373270  0.204550 -1.065491  three
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218   four
# 2013-01-06  0.006860  1.196373  1.928233  0.121686  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -2.179509 -1.474523  0.060685  0.848741   two
# 2013-01-05  0.706045  0.614304 -1.141441  1.417218  four

# %%
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range('20130102',periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0],'A'] = 0

# %%
df.iat[0,1] = 0

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.352614  5
# 2013-01-02 -0.974847 -0.024409  0.666192  5
# 2013-01-03 -2.179509 -1.474523  0.060685  5
# 2013-01-04  1.163199  0.373270  0.204550  5
# 2013-01-05  0.706045  0.614304 -1.141441  5
# 2013-01-06  0.006860  1.196373  1.928233  5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.352614 -5
# 2013-01-02 -0.974847 -0.024409 -0.666192 -5
# 2013-01-03 -2.179509 -1.474523 -0.060685 -5
# 2013-01-04 -1.163199 -0.373270 -0.204550 -5
# 2013-01-05 -0.706045 -0.614304 -1.141441 -5
# 2013-01-06 -0.006860 -1.196373 -1.928233 -5

# %%
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D   E
# 2013-01-01  0.000000  0.000000 -0.352614  5   1
# 2013-01-02 -0.974847 -0.024409  0.666192  5   1
# 2013-01-03 -2.179509 -1.474523  0.060685  5 NaN
# 2013-01-04  1.163199  0.373270  0.204550  5 NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D  E
# 2013-01-01  0.000000  0.000000 -0.352614  5  1
# 2013-01-02 -0.974847 -0.024409  0.666192  5  1

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  E
# 2013-01-01  0.000000  0.000000 -0.352614  5  1
# 2013-01-02 -0.974847 -0.024409  0.666192  5  1
# 2013-01-03 -2.179509 -1.474523  0.060685  5  5
# 2013-01-04  1.163199  0.373270  0.204550  5  5

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.213042
# B    0.114169
# C    0.227601
# D    5.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.161846
# 2013-01-02    1.166734
# 2013-01-03    0.351663
# 2013-01-04    1.685255
# 2013-01-05    1.294727
# 2013-01-06    2.032866
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
s
# Out:
# 2013-01-01   NaN
# 2013-01-02   NaN
# 2013-01-03     1
# 2013-01-04     3
# 2013-01-05     5
# 2013-01-06   NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C   D
# 2013-01-01       NaN       NaN       NaN NaN
# 2013-01-02       NaN       NaN       NaN NaN
# 2013-01-03 -3.179509 -2.474523 -0.939315   4
# 2013-01-04 -1.836801 -2.626730 -2.795450   2
# 2013-01-05 -4.293955 -4.385696 -6.141441   0
# 2013-01-06       NaN       NaN       NaN NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000 -0.352614   5
# 2013-01-02 -0.974847 -0.024409  0.313578  10
# 2013-01-03 -3.154356 -1.498932  0.374262  15
# 2013-01-04 -1.991157 -1.125662  0.578812  20
# 2013-01-05 -1.285112 -0.511358 -0.562629  25
# 2013-01-06 -1.278252  0.685015  1.365603  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.342708
# B    2.670896
# C    3.069674
# D    0.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    1
# 1    4
# 2    2
# 3    6
# 4    4
# 5    5
# 6    4
# 7    2
# 8    5
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 4    4
# 5    2
# 2    2
# 6    1
# 1    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.913803  0.231636  1.257595 -0.956660
# 1  0.603196 -1.214189 -0.580770  0.360974
# 2 -0.507501  1.111723 -1.706799  0.296677
# 3  1.764311  0.613397  0.574901 -0.110238
# 4 -0.070237  0.635287 -0.747599 -1.403187
# 5  0.189858 -2.555493  0.991115 -0.172333
# 6 -1.338641  0.609294  0.887516  0.593887
# 7 -0.011171  1.567696  0.802113 -0.617661
# 8 -1.724618  0.195692 -0.033964 -0.756577
# 9  0.404841 -0.902026 -1.719887  0.946270

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.913803  0.231636  1.257595 -0.956660
# 1  0.603196 -1.214189 -0.580770  0.360974
# 2 -0.507501  1.111723 -1.706799  0.296677
# 3  1.764311  0.613397  0.574901 -0.110238
# 4 -0.070237  0.635287 -0.747599 -1.403187
# 5  0.189858 -2.555493  0.991115 -0.172333
# 6 -1.338641  0.609294  0.887516  0.593887
# 7 -0.011171  1.567696  0.802113 -0.617661
# 8 -1.724618  0.195692 -0.033964 -0.756577
# 9  0.404841 -0.902026 -1.719887  0.946270

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -0.049381  0.566538 -0.438995 -1.066273
# 1 -1.747521 -0.187566  1.621607  0.554194
# 2 -0.396522 -0.689164  2.144505  0.403101
# 3 -0.183562 -0.970723  0.202463  1.111298
# 4 -0.427869 -0.663021  0.901993 -1.920359
# 5  0.509422  0.355483 -0.679725 -1.501808
# 6  1.200153 -1.713481  0.413100 -0.432302
# 7  0.557385 -1.193221 -1.402143  1.396971

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.049381  0.566538 -0.438995 -1.066273
# 1 -1.747521 -0.187566  1.621607  0.554194
# 2 -0.396522 -0.689164  2.144505  0.403101
# 3 -0.183562 -0.970723  0.202463  1.111298
# 4 -0.427869 -0.663021  0.901993 -1.920359
# 5  0.509422  0.355483 -0.679725 -1.501808
# 6  1.200153 -1.713481  0.413100 -0.432302
# 7  0.557385 -1.193221 -1.402143  1.396971
# 8 -0.183562 -0.970723  0.202463  1.111298

# %%
 df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  0.405036  0.735456
# 1  bar    one  0.195380 -0.003349
# 2  foo    two -1.400212 -0.273832
# 3  bar  three  1.895381  0.680828
# 4  foo    two -0.513956  0.812722
# 5  bar    two  0.352440 -0.557531
# 6  foo    one -0.530127  0.124434
# 7  foo  three  0.549779  0.894950

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.443201  0.119948
# foo -1.489479  2.293731

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.195380 -0.003349
#     three  1.895381  0.680828
#     two    0.352440 -0.557531
# foo one   -0.125091  0.859890
#     three  0.549779  0.894950
#     two   -1.914168  0.538891

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.756395 -0.229748
#       two    -1.493419  0.205576
# baz   one    -1.406577  0.427837
#       two    -1.708665  1.289308

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.756395
#                B   -0.229748
#        two     A   -1.493419
#                B    0.205576
# baz    one     A   -1.406577
#                B    0.427837
#        two     A   -1.708665
#                B    1.289308
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.756395 -0.229748
#       two    -1.493419  0.205576
# baz   one    -1.406577  0.427837
#       two    -1.708665  1.289308

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.756395 -1.493419
#       B -0.229748  0.205576
# baz   A -1.406577 -1.708665
#       B  0.427837  1.289308

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.756395 -1.406577
#        B -0.229748  0.427837
# two    A -1.493419 -1.708665
#        B  0.205576  1.289308

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.435480  0.506014
# 1     one  B  foo  0.265253 -0.623195
# 2     two  C  foo -0.883288 -1.056741
# 3   three  A  bar -1.625056 -1.121834
# 4     one  B  bar  0.117806 -0.190268
# 5     one  C  bar  1.704396  1.897596
# 6     two  A  foo  1.229554  0.138010
# 7   three  B  foo -0.097047 -0.040298
# 8     one  C  foo  0.853103 -1.106113
# 9     one  A  bar  0.592565  0.580488
# 10    two  B  bar  0.379646  1.958410
# 11  three  C  bar  0.432003  0.441040

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.592565 -1.435480
#       B  0.117806  0.265253
#       C  1.704396  0.853103
# three A -1.625056       NaN
#       B       NaN -0.097047
#       C  0.432003       NaN
# two   A       NaN  1.229554
#       B  0.379646       NaN
#       C       NaN -0.883288

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min', how='sum')
# Out:
# 2012-01-01    22328
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -0.851002
# 2012-03-07   -1.336869
# 2012-03-08   -0.288195
# 2012-03-09   -0.439018
# 2012-03-10    0.148969
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.851002
# 2012-03-07 00:00:00+00:00   -1.336869
# 2012-03-08 00:00:00+00:00   -0.288195
# 2012-03-09 00:00:00+00:00   -0.439018
# 2012-03-10 00:00:00+00:00    0.148969
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.851002
# 2012-03-06 19:00:00-05:00   -1.336869
# 2012-03-07 19:00:00-05:00   -0.288195
# 2012-03-08 19:00:00-05:00   -0.439018
# 2012-03-09 19:00:00-05:00    0.148969
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    0.409264
# 2012-02-29    0.404120
# 2012-03-31   -0.347455
# 2012-04-30    0.019293
# 2012-05-31    0.830535
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.409264
# 2012-02    0.404120
# 2012-03   -0.347455
# 2012-04    0.019293
# 2012-05    0.830535
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.409264
# 2012-02-01    0.404120
# 2012-03-01   -0.347455
# 2012-04-01    0.019293
# 2012-05-01    0.830535
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    0.802340
# 1990-06-01 09:00    0.685101
# 1990-09-01 09:00   -0.042370
# 1990-12-01 09:00   -1.165565
# 1991-03-01 09:00    0.899712
# Freq: H, dtype: float64

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.